# %% [markdown]
# 1. What is the difference between enclosing a list comprehension in square brackets and parentheses?

# %% [markdown]
# - When enclosing a list comprehension in square brackets, it creates a list. The result is a new list object that contains the elements generated by the list comprehension.
# - When enclosing a list comprehension in parentheses, it creates a generator expression. The result is a generator object that produces the elements on-the-fly as they are requested, rather than generating the entire list upfront.

# %% [markdown]
# 2. What is the relationship between generators and iterators?

# %% [markdown]
# - Generators and iterators are closely related concepts in Python.
# - Generators are a type of iterator. They are functions that use the yield statement to produce a sequence of values. Each time a value is yielded, the generator pauses its execution and remembers its state.
# - Iterators are objects that implement the iterator protocol, which includes the __iter__() and __next__() methods. Iterators allow you to iterate over a sequence of values one at a time, using the next() function or a for loop.

# %% [markdown]
# 3. What are the signs that a function is a generator function?

# %% [markdown]
# - A function is a generator function if it contains the yield statement.
# - The presence of the yield statement indicates that the function will generate a sequence of values and can be used as a generator.

# %% [markdown]
# 4. What is the purpose of a yield statement?

# %% [markdown]
# - The yield statement is used in generator functions to produce a value and suspend the function's execution temporarily.
# - When a value is yielded, the current state of the function is saved, and the value is returned to the caller. The function can then be resumed from where it left off the next time a value is requested.
# - Multiple values can be yielded in a generator function, allowing it to produce a sequence of values on-the-fly without generating the entire sequence upfront.

# %% [markdown]
# 5. What is the relationship between map calls and list comprehensions? Make a comparison and contrast between the two.

# %% [markdown]
# - Both map calls and list comprehensions are used to transform and process iterable objects, such as lists.
# - Map calls apply a given function to each element of an iterable and return a new iterable with the results. The result is - obtained by calling the function on each element individually.
# - List comprehensions provide a concise syntax for creating new lists by applying an expression to each element of an - iterable. They construct the entire list upfront and return it as a new list object.
# - List comprehensions can often be more readable and expressive than map calls, especially for simple transformations or filtering operations.
# - Map calls may be more suitable when working with functions that are not easily expressed as simple expressions, or when working with multiple iterables simultaneously.
